# %%
from pymodm import connect
import pymongo

# %%
def resize_display(image_path):
    """
    It takes an image path, opens the image, resizes it to half the ealier
    size, display as a whole piece, then show in main window by converts
    it to a Tkinter PhotoImage, and returns a resized image
    containing the image

    :param image_path: The path to the image to display
    :return: The image is being returned.
    """
    image = Image.open(image_path)
    image = image.resize((image.width // 2, image.height // 2))
    return image

# %%
from tkinter import ttk
import base64
from tkinter import filedialog
from PIL import Image, ImageTk
import matplotlib.pyplot as plt
import requests
import tkinter as tk

# %%
root = tk.Tk()
patient_name_entry = ttk.Entry(root, width=20, textvariable='')
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /workspaces/TEST_CODESPACES/test/flask/mongo.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bechodpp-nogibjj-test-codespaces-pq6p7x66p55f774q/workspaces/TEST_CODESPACES/test/flask/mongo.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> root = tk.Tk()
#       <a href='vscode-notebook-cell://codespaces%2Bechodpp-nogibjj-test-codespaces-pq6p7x66p55f774q/workspaces/TEST_CODESPACES/test/flask/mongo.ipynb#X35sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> patient_name_entry = ttk.Entry(root, width=20, textvariable='')
#
# File /opt/python/3.10.4/lib/python3.10/tkinter/__init__.py:2299, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2297         baseName = baseName + ext
#    2298 interactive = False
# ...

# %%
connect("mongodb+srv://echodpp:WiKMRhwb3symh7bL@bme547.kgv09vh.mongodb.net/final_db?retryWrites=true&w=majority")

# %%
def check():
    if a:
        save1()
        save3()
    else:
        save2()

# %%
a =False
check()
# Out:
# b

# %%
def save1():
    print('a')
def save2():
    print('b')
def save3():
    print('c')

# %%
from pymodm import MongoModel, fields
class Patient(MongoModel):
    rec_no = fields.IntegerField(primary_key=True)
    patient_name = fields.CharField()
    hr = fields.ListField()
    ECG_trace = fields.ListField()
    dt = fields.ListField()
    med_im = fields.ListField()

# %%
def get_info(input_id):
    rec_no_list = []
    for i in Patient.objects.all():
        rec_no_list.append(i.rec_no)
    if input_id in rec_no_list:
        return Patient.objects.raw({"_id": input_id}).first()
    else:
        return False

# %%
rec_no_list = []
for i in Patient.objects.all():
    rec_no_list.append(i.rec_no)

# %%
Patient.objects.raw({"_id": 3}).first()
# Out:
# Patient(rec_no=3, hr=[74.0, 83.0], ECG_trace=['...', '...'], med_im=['...', '...'], dt=[datetime.datetime(2022, 12, 6, 15, 39, 39, 353000), datetime.datetime(2022, 12, 6, 15, 40, 49, 648000)], patient_name='echo')

# %%
patient = Patient(
            rec_no=1,
            patient_name='ec',
        )

# %%
patient.rec_no
# Out:
# 1

# %%
patientname=False
if patientname :
    print('Patient name is empty')
else:
    print('Patient name is False')
# Out:
# Patient name is False

# %%
from pymodm import MongoModel, fields
class Patient(MongoModel):
    rec_no = fields.IntegerField(primary_key=True)
    patient_name = fields.CharField()
    hr = fields.ListField()
    ECG_trace = fields.ListField()
    dt = fields.ListField()
    med_im = fields.ListField()

# %%
patient.dt
# Out:
# datetime.datetime(2022, 12, 3, 15, 15, 43, 608000)

# %%
patient = Patient.objects.raw({"_id": 5}).first()

# %%
import datetime
dt=datetime.datetime.now()

# %%
type(dt)
# Out:
# datetime.datetime

# %%
patient
# Out:
# Patient(rec_no=5, patient_name='roza', dt=datetime.datetime(2022, 12, 3, 15, 15, 43, 608000))

# %%
patient.hr.append(100)

# %%
new_patient = Patient(
            rec_no=update['rec_no'],
            patient_name=update['patient_name'],
            hr=update['hr'],
            ECG_trace=update['ECG_trace'],
            dt=update['dt'],
        )

# %%
update = {'rec_no':1, 'patient_name':"sona2", 'med_im':"no2", 'hr':None , 'ECG_trace':"normal22", 'dt':None}

# %%
patient.save()
# Out:
# Patient(patient_name='sona2', med_im='no2', ECG_trace='normal22', hr=[792, 22, 100], rec_no=1, dt='2020-12-11 11:11:11')

# %%
new_patient = Patient(rec_no=1, patient_name="sona2", med_im= "no2", hr=[792,22], ECG_trace="normal22", dt="2020-12-11 11:11:11")
new_patient.save()
# Out:
# Patient(med_im='no2', ECG_trace='normal22', hr=[792, 22], dt='2020-12-11 11:11:11', rec_no=1, patient_name='sona2')

# %%
for patient in Patient.objects.raw({}):
    print(patient.rec_no)
# Out:
# 1
# 2
# 3
# 5
# 0

# %%
User.objects.raw({"_id": "suyash@suyashkumar.com"}).first()
# Out:
# 'Suyash'
