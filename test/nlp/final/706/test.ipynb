# %%
data=[{'label': 'LABEL_6', 'score': 0.3822253346443176}]
# only want the result of label
data[0]['label']

# %%
data[0]['label']
# Out:
# 'LABEL_6'
# Bad pipe message: %s [b"'0OZ>\x93,n\xbc\xa3e=N%r\x89\x0c\x9d z\x1b\xfe\x07\x19)e?\xc9\xd8\xd7\xd9V\x7f \xc3b\xe5\x90\x8b\xbd\xc5\xc6\xb5\xea\xb5}\xdcD9lN\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x80-N\xc5\x97<\xe4\xb5\xbd\x9c\x94\xe0\x08\xe5\x19tx\xf5\xb8M"]
# ...

# %%
import gradio as gr
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/TEST_CODESPACES/test/nlp/final/706/test.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bechodpp-nogibjj-test-codespaces-pq6p7x66p55f774q/workspaces/TEST_CODESPACES/test/nlp/final/706/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import gradio as gr
#       <a href='vscode-notebook-cell://codespaces%2Bechodpp-nogibjj-test-codespaces-pq6p7x66p55f774q/workspaces/TEST_CODESPACES/test/nlp/final/706/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from transformers import pipeline
#
# ModuleNotFoundError: No module named 'gradio'
