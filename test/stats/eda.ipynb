# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df=pd.read_csv('Life Expectancy Data.csv')

# %%
df=df.dropna()

# %%
df.groupby('Year').count()
# Out:
#       Country  Status  Life expectancy   Adult Mortality  infant deaths  \
# Year
# 2000       61      61                61               61             61
# 2001       66      66                66               66             66
# 2002       81      81                81               81             81
# 2003       95      95                95               95             95
# 2004      103     103               103              103            103
# 2005      110     110               110              110            110
# 2006      114     114               114              114            114
# 2007      120     120               120              120            120
# 2008      123     123               123              123            123
# 2009      126     126               126              126            126
# 2010      128     128               128              128            128
# 2011      130     130               130              130            130
# ...

# %%
df=df[df['Year']==2014]

# %%
profile = ProfileReport(df, title="2014 Life Expectancy Data")
profile.to_file("life.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df=df.drop(['Year'],axis=1)

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 1 to 2923
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          131 non-null    object
#  1   Status                           131 non-null    object
#  2   Life expectancy                  131 non-null    float64
#  3   Adult Mortality                  131 non-null    float64
#  4   infant deaths                    131 non-null    float64
#  5   Alcohol                          131 non-null    float64
#  6   percentage expenditure           131 non-null    float64
#  7   Hepatitis B                      131 non-null    float64
#  8   Measles                          131 non-null    float64
#  9    BMI                             131 non-null    float64
#  10  under-five deaths                131 non-null    float64
# ...

# %%
cols = df.columns.drop(['Country', 'Status']) 
df[cols] = df[cols].astype('float')
# Out:
#           Country      Status  Life expectancy   Adult Mortality  \
# 1     Afghanistan  Developing              59.9            271.0
# 17        Albania  Developing              77.5              8.0
# 33        Algeria  Developing              75.4             11.0
# 49         Angola  Developing              51.7            348.0
# 81      Argentina  Developing              76.2            118.0
# ...           ...         ...               ...              ...
# 2811      Uruguay  Developing              76.8            117.0
# 2827   Uzbekistan  Developing              69.2            184.0
# 2843      Vanuatu  Developing              71.7            134.0
# 2907       Zambia  Developing              61.1            314.0
# 2923     Zimbabwe  Developing              59.2            371.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1              64.0     0.01               73.523582         62.0     492.0
# ...

# %%
import os  
os.makedirs('/workspaces/TEST_CODESPACES/test/stats', exist_ok=True) 
df.to_csv('/workspaces/TEST_CODESPACES/test/stats/2014_Life_Data.csv')
# Out:
# Bad pipe message: %s [b'8I\x0f\x1b\x10\x8f4\xfb\x9dE\xdc\xd1\xdd\x11\xea\xd3Z\xfb \xdd\xf4\x80\x8e\xd4\xc6o\x0459\xd7s\x1d\xdc\r\x92\xe1m\xb9\x7f\x00\xb5\xf7%\xac\n\x98\xce\x1c\x89\xc6\x81\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c']
# Bad pipe message: %s [b'\x05\x03\x06', b'\x07\x08']
# Bad pipe message: %s [b'7\xa0;?\x93W\x17\x7f\xef\x08\xc4|\xb7\xb6\xc8)TO 9[5\xcd\xf1\xfa\xe4K\x1c^\xa4)5\xef\xe2u\x01\x8f\x89^`\xa3\xdc\xce\xf3\xff\xead@\x07\x95{\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00', b'']
# Bad pipe message: %s [b'\t\x08\n\x08\x0b\x08\x04']
# ...
